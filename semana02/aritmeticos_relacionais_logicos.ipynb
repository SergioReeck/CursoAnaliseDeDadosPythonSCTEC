# %% [markdown]
# # Operadores Aritméticos, Relacionais e Lógicos.

# %% [markdown]
# ## Exemplo - Aluguel de Carro
#
# Escreva um programa que pergunte a quantidade de km percorridos por um carro alugado pelo usuário, assim como a quantidade de dias pelos quais o carro foi alugado. Calcule o preço, sabendo que o carro custa 60,00 reais por dia e 0,15 centavos por km rodado.

# %%
# Entrada de dados
qtde_km = int(input("Informe a quantidade de km percorridos: "))
qtde_dias = int(input("Informe a quantidade de dias em que o carro foi alugado: "))

# Cálculos
valor_diaria = qtde_dias * 60.00
valor_km = qtde_km * 0.15
total = valor_diaria + valor_km

# Saída de dados
print(f"O valor total a pagar é de R${total:.2f}")

# %% [markdown]
# ## Exemplo - Pode Dirigir?

# %%
idade = 20
tem_carteira = True

pode_dirigir = idade >=18 and tem_carteira
print(f"Pode dirigir? {pode_dirigir}")

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Escreva uma expressão para determinar se uma pessoa deve ou não pagar imposto. Considere que pagam imposto pessoas cujo salário é maior que 5 mil reais.

# %%
salario = float(input("Informe o salário: "))
deve_pagar_imposto = salario > 5000
print(f"O funcionário deve pagar imposto? {deve_pagar_imposto}")

# %% [markdown]
# ### Exercício 2
#
# Escreva uma expressão que será utilizada para decidir se um aluno foi ou não aprovado. Para ser aprovado, a média final do aluno deve ser maior ou igual a 7. Considere que o aluno cursa apenas três matérias, e que a nota de cada matéria está armazenada nas seguintes variávies:
#
# - materia_1
# - materia_2
# - materia_3
#
# Utilize como aprovação: True ou False

# %%
materia_1 = float(input("Informe a nota da matéria 1: "))
materia_2 = float(input("Informe a nota da matéria 2: "))
materia_3 = float(input("Informe a nota da matéria 3: "))

media_final = (materia_1 + materia_2 + materia_3) / 3
aprovado = media_final >= 7
print(f"O aluno foi aprovado? {aprovado}, com média {media_final:.2f}")

# %% [markdown]
# ## Exemplo - Frete Grátis
#
# Você está desenvolvendo o sistema de uma loja online. O cliente terá direito ao "frete grátis" se atender a pelo menos uma das seguintes regras de negócio. **Regra 1:** Ele precisa ser um cliente "Premium" e o valor da compra deve ser maior ou igual a 100,00 reais. **Regra 2:** Ele pode ser um cliente comum, mas o valor da compra precisa ser maior que 250,00 reais e os produtos da compra não podem estar em promoção.
#
# Dica: Utilize "input()" para comparar cenários. Variáveis do sistema:
#
# - status_cliente (texto: "Premium" ou "Normal")
# - valor_compra (número decimal)
# - produto_promocao (booleano: True ou False)

# %%
status_cliente = input("Status do cliente? ")
valor_compra = float(input("Qual o valor da compra?"))
produto_promocao = (input("Produto em promoção? (Sim ou Não)"))

frete_gratis = (
    (status_cliente == "Premium" and valor_compra >= 100.00) # Regra 1
     or
    (status_cliente == "Normal" and valor_compra > 250.00 and produto_promocao == "Não") # Regra 2
)

print(f"Frete grátis? {frete_gratis}")

# %% [markdown]
# # Estruturas Condicionais if, elif e else

# %% [markdown]
# ## Exemplo - Média com Estrutura Condicional

# %%
materia_1 = float(input("Informe a nota da matéria 1: "))
materia_2 = float(input("Informe a nota da matéria 2: "))
materia_3 = float(input("Informe a nota da matéria 3: "))

media_final = (materia_1 + materia_2 + materia_3) / 3

if media_final >= 7:
    print(f"Aprovado com média {media_final:.2f}")
else:
    print(f"Reprovado com média {media_final:.2f}")

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Escreva um programa que pergunte a velocidade do carro de um usuário. Caso ultrapasse 80 km/h, exiba um mensagem dizendo que o usuário foi multado. Nesse caso, exiba a velocidade, além do valor da multa, cobrando 5,00 reais por km acima de 80 km/h.

# %%
velocidade = int(input("Informe a velocidade do carro: "))

if velocidade > 80:
    multa = (velocidade - 80) * 5
    print(f"Você foi multado! Sua velocidade foi de {velocidade} km\\h e o valor da multa é de R$ {multa:.2f}.")

# %% [markdown]
# # Estruturas Aninhadas

# %% [markdown]
# ## Exemplo - Conta de Telefone com Três Faixas de Preço

# %%
minutos = int(input("Informe a quantidade de minutos utilizados este mês: "))

if minutos < 200:
  preco = 0.20
else:
  if minutos < 400:
    preco = 0.18
  else:
    preco = 0.15

print(f"O valor a pagar é de R$ {preco * minutos:.2f}")

# %%
categoria = int(input(
    "Escolha a categoria do produto:\n" \
    "1 - Eletrônicos\n" \
    "2 - Roupas\n" \
    "3 - Alimentos\n" \
    "4 - Esportivos\n" \
    "5 - Utensílios\n" \
    ))

if categoria == 1:
    print("Você escolheu a categoria Eletrônicos.")
elif categoria == 2:
    print("Você escolheu a categoria Roupas.")
elif categoria == 3:
    print("Você escolheu a categoria Alimentos.")
elif categoria == 4:
    print("Você escolheu a categoria Esportivos.")
elif categoria == 5:
    print("Você escolheu a categoria Utensílios.")
else:
    print("Categoria inválida.")

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Escreva um programa que leia dois números e pergunte qual operação você deseja realizar. Você deve poder calcular soma, subtração, multiplicação e divisão. Exiba o resultado da operação solicitada.

# %%
# Entrada de Dados

# Parou no minuto 01:48:45

# %% [markdown]
# ### Execício 2
#
# Escreva um programa que pergunte o salário do funcionário e calcule o valor do aumento. Para salários superiores à 2.0000,00 reais, calcule um aumento de 10 por cento. Para salários inferiores ou iguais, um aumento de 15 por cento. Exiba o valor do salário atual, o percentual de aumento, o valor de aumento, e o salário após aumento.
