# %% [markdown]
# # Exemplo - Manipulação de Arquivos com Python

# %%
with open("produtos.txt", "w") as arquivo:

    arquivo.write("Notebook;3500\n")
    arquivo.write("Mouse;100\n")

arquivo.close()

# %%
with open("produtos.txt", "r") as leitura:

    print(leitura.read())
# Out:
# Notebook;3500
# Mouse;100
