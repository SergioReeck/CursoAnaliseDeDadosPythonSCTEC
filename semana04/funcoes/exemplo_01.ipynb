# %%
def saudacao(nome):
    print(f"Olá, {nome}!")

# %%
saudacao("Sérgio")
# Out:
# Olá, Sérgio!

# %%
def soma(a, b):
    soma = a + b
    return soma

# %%
resultado = soma(8, 5)

# %%
print(resultado)
# Out:
# 13
