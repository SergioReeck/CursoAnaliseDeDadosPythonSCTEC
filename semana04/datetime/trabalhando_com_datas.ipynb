# %%
from datetime import datetime

# %%
data_processamento = datetime.now()
print(data_processamento)
# Out:
# 2026-07-27 16:37:12.776118

# %%
print(f"Data: {data_processamento.strftime("%d/%m/%Y")}")
# Out:
# Data: 27/07/2026
