# %%
import pandas as pd
import openpyxl

# %%
dados = {
    "nome": ["Ana", "Carlos", "Fernanda"],
    "nota": [8, 7, 10]
}

# %%
df_alunos = pd.DataFrame(dados)

# %%
df_alunos
# Out:
#        nome  nota
# 0       Ana     8
# 1    Carlos     7
# 2  Fernanda    10

# %%
df_alunos.to_excel("alunos.xlsx", index=False)

# %%
df_lido = pd.read_excel("alunos.xlsx")

# %%
df_lido
# Out:
#        nome  nota
# 0       Ana     8
# 1    Carlos     7
# 2  Fernanda    10

# %%
print(df_lido.iloc[0])
# Out:
# nome    Ana
# nota      8
# Name: 0, dtype: object
