# %% [markdown]
# # Exemplo - Manipulação de Arquivos com Python

# %%
arquivo = open("produtos.txt", "w")

arquivo.write("Notebook;3500\n")
arquivo.write("Mouse;100\n")

arquivo.close()

# %%
leitura = open("produtos.txt", "r")

print(leitura.read())

leitura.close()
# Out:
# Notebook;3500
# Mouse;100
