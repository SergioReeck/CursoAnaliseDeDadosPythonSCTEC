# %%
import re # expressões regulares REGEX
import pandas as pd

# %%
dados = {"nome": ["Ana", "Carlos", "Maria", "José"],
        "telefone":["(47) 99999-1111", "47 98888-2222", "+55 (47) 97777-3333", "47966664444"]}

# %%
df = pd.DataFrame(dados)

# %%
df
# Out:
#      nome             telefone
# 0     Ana      (47) 99999-1111
# 1  Carlos        47 98888-2222
# 2   Maria  +55 (47) 97777-3333
# 3    José          47966664444

# %%
df_copy = df

# %%
df["telefone"] = df["telefone"].apply(lambda x: re.sub(r"\D", "", x))

# %%
df["telefone"] = df["telefone"].apply(lambda x: re.sub(r"[^0-9]", "", x))

# %%
df
# Out:
#      nome       telefone
# 0     Ana    47999991111
# 1  Carlos    47988882222
# 2   Maria  5547977773333
# 3    José    47966664444

# %%
df_copy
# Out:
#      nome       telefone
# 0     Ana    47999991111
# 1  Carlos    47988882222
# 2   Maria  5547977773333
# 3    José    47966664444
